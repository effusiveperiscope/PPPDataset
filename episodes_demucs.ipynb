# %%
MLP_EPISODES_DIRECTORIES = [
    "D:\MLP_Samples\AIData\PPP Cleans"
]
#EPISODE_EXTENSIONS = ['mp4', 'mkv']
EPISODE_EXTENSIONS = ['flac']
EPISODE_PATTERNS = [r's(\d{2})e(\d{2})', r'S(\d{2})E(\d{2})', r'(\d{2})x(\d{2})']

import os
import re

episode_index = {}
for d in MLP_EPISODES_DIRECTORIES:
    for root,_,files in os.walk(d):
        for f in files:
            f_ext = f.split('.')[-1]
            if not f_ext in EPISODE_EXTENSIONS:
                continue
            for pattern in EPISODE_PATTERNS:
                match_s = re.search(pattern, f)
                if match_s:
                    sig = f's{match_s.group(1)}e{match_s.group(2)}'
                    episode_index[sig] = os.path.join(root,f).replace('\\','/')
                
import subprocess
from pydub import AudioSegment
import io
def extract_center_channel(vid_path):
    #command = ['ffmpeg', '-i', vid_path, '-filter_complex',
    #    'channelsplit=channel_layout=5.1:channels=FC[FC]', '-map', '[FC]',
    #    '-c:a', 'pcm_s32le',
    #     '-f', 'wav', '-']
    #process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    #output, errs = process.communicate()
    #f = io.BytesIO(output)
    #audio_segment = AudioSegment.from_file(f, format='wav')
    audio_segment = AudioSegment.from_file(vid_path)
    return audio_segment

from demucs import pretrained
from demucs.apply import apply_model
import numpy as np
from pathlib import Path
import torch
import scipy.io.wavfile
class DemucsModels:
    def __init__(self, repo, models):
        if type(repo) == str:
            repo = Path(repo)
        self.models = []
        self.model_names = []
        for model in models:
            self.models.append(pretrained.get_model(name=model, repo=repo))
            self.model_names.append(model)

    def apply(self, x):
        outputs = []
        for model in self.models:
            out = apply_model(model, torch.from_numpy(x).T.unsqueeze(0),
                device='cuda')[0]
            out_dict = {}
            for name, source in zip(model.sources, out):
                out_dict[name] = source
            vocals = out_dict['vocals'].numpy().T
            outputs.append(vocals)
        return outputs

    def process_ep(self, specifier='s01e01', dump_to_folder=None):
        assert specifier in episode_index
        if os.path.exists(dump_to_folder):
            print(f"Skipping folder {dump_to_folder}")
            return
        if dump_to_folder is not None:
            os.makedirs(dump_to_folder, exist_ok=True)

        print(f"processing {specifier}")
        print("extracting center")
        fc = extract_center_channel(episode_index[specifier])
        sr = fc.frame_rate
        fc_dbfs = fc.dBFS
        fc_orig = fc
        fc = np.array(fc.get_array_of_samples())
        fc = np.column_stack((fc,fc))
        fc = (fc / (2 ** 32 - 1)).astype(np.float32)

        print("applying demucs")
        demucs_outputs = self.apply(fc)
        print("finished applying demucs")
        for i,do in enumerate(demucs_outputs):
            do_io = io.BytesIO()
            scipy.io.wavfile.write(do_io, 48000, do)
            do_io.seek(0)
            do_snd = AudioSegment.from_wav(do_io).set_channels(1)
            print(f'dbfs adjust {fc_dbfs - do_snd.dBFS}')
            do_snd = do_snd.apply_gain(fc_dbfs - do_snd.dBFS)
            if dump_to_folder is not None:
                do_snd.export(
                    os.path.join(dump_to_folder,f'{specifier}_demu{i}.flac'), format='flac')

        if dump_to_folder is not None:
            # These are more for previews than anything
            fc_orig.export(
                os.path.join(dump_to_folder,f'{specifier}.flac'),
                format='flac')
        print('done')

demucsmodels = DemucsModels(repo="D:/Code/demucs/release_models",
    models=["SFX_separation_epoch_190", "SFX_separation_v2_epoch_338"])
for k in episode_index.keys():
    dump_folder = os.path.join('episode_process_dumps',k)
    demucsmodels.process_ep(specifier=k, dump_to_folder=dump_folder)


# Objective: Compare 0. original (i.e. Clipper's choice), 1. sfx demucs v1, 2. sfx demucs v2
# Out:
# Skipping folder episode_process_dumps\s01e01
# Skipping folder episode_process_dumps\s01e02
# Skipping folder episode_process_dumps\s01e03
# Skipping folder episode_process_dumps\s01e04
# Skipping folder episode_process_dumps\s01e05
# Skipping folder episode_process_dumps\s01e06
# Skipping folder episode_process_dumps\s01e07
# Skipping folder episode_process_dumps\s01e08
# Skipping folder episode_process_dumps\s01e09
# Skipping folder episode_process_dumps\s01e10
# Skipping folder episode_process_dumps\s01e11
# Skipping folder episode_process_dumps\s01e12
# Skipping folder episode_process_dumps\s01e13
# Skipping folder episode_process_dumps\s01e14
# Skipping folder episode_process_dumps\s01e15
# Skipping folder episode_process_dumps\s01e16
# Skipping folder episode_process_dumps\s01e17
# Skipping folder episode_process_dumps\s01e18
# Skipping folder episode_process_dumps\s01e19
# Skipping folder episode_process_dumps\s01e20
# Skipping folder episode_process_dumps\s01e21
# Skipping folder episode_process_dumps\s01e22
# Skipping folder episode_process_dumps\s01e23
# Skipping folder episode_process_dumps\s01e24
# Skipping folder episode_process_dumps\s01e25
# Skipping folder episode_process_dumps\s01e26
# Skipping folder episode_process_dumps\s02e01
# Skipping folder episode_process_dumps\s02e02
# Skipping folder episode_process_dumps\s02e03
# Skipping folder episode_process_dumps\s02e04
# Skipping folder episode_process_dumps\s02e05
# Skipping folder episode_process_dumps\s02e06
# Skipping folder episode_process_dumps\s02e07
# Skipping folder episode_process_dumps\s02e08
# Skipping folder episode_process_dumps\s02e09
# Skipping folder episode_process_dumps\s02e10
# Skipping folder episode_process_dumps\s02e11
# Skipping folder episode_process_dumps\s02e12
# Skipping folder episode_process_dumps\s02e13
# Skipping folder episode_process_dumps\s02e14
# Skipping folder episode_process_dumps\s02e15
# Skipping folder episode_process_dumps\s02e16
# Skipping folder episode_process_dumps\s02e17
# Skipping folder episode_process_dumps\s02e18
# Skipping folder episode_process_dumps\s02e19
# Skipping folder episode_process_dumps\s02e20
# Skipping folder episode_process_dumps\s02e21
# Skipping folder episode_process_dumps\s02e22
# Skipping folder episode_process_dumps\s02e23
# Skipping folder episode_process_dumps\s02e24
# Skipping folder episode_process_dumps\s02e25
# Skipping folder episode_process_dumps\s02e26
# Skipping folder episode_process_dumps\s03e01
# Skipping folder episode_process_dumps\s03e02
# Skipping folder episode_process_dumps\s03e03
# Skipping folder episode_process_dumps\s03e04
# Skipping folder episode_process_dumps\s03e05
# Skipping folder episode_process_dumps\s03e06
# Skipping folder episode_process_dumps\s03e07
# Skipping folder episode_process_dumps\s03e08
# Skipping folder episode_process_dumps\s03e09
# Skipping folder episode_process_dumps\s03e10
# Skipping folder episode_process_dumps\s03e11
# Skipping folder episode_process_dumps\s03e12
# Skipping folder episode_process_dumps\s03e13
# Skipping folder episode_process_dumps\s04e01
# Skipping folder episode_process_dumps\s04e02
# Skipping folder episode_process_dumps\s04e03
# Skipping folder episode_process_dumps\s04e04
# Skipping folder episode_process_dumps\s04e05
# Skipping folder episode_process_dumps\s04e06
# Skipping folder episode_process_dumps\s04e07
# Skipping folder episode_process_dumps\s04e08
# Skipping folder episode_process_dumps\s04e09
# Skipping folder episode_process_dumps\s04e10
# Skipping folder episode_process_dumps\s04e11
# Skipping folder episode_process_dumps\s04e12
# Skipping folder episode_process_dumps\s04e13
# Skipping folder episode_process_dumps\s04e14
# Skipping folder episode_process_dumps\s04e15
# Skipping folder episode_process_dumps\s04e16
# Skipping folder episode_process_dumps\s04e17
# Skipping folder episode_process_dumps\s04e18
# Skipping folder episode_process_dumps\s04e19
# Skipping folder episode_process_dumps\s04e20
# Skipping folder episode_process_dumps\s04e21
# Skipping folder episode_process_dumps\s04e22
# Skipping folder episode_process_dumps\s04e23
# Skipping folder episode_process_dumps\s04e24
# Skipping folder episode_process_dumps\s04e25
# Skipping folder episode_process_dumps\s04e26
# Skipping folder episode_process_dumps\s05e01
# Skipping folder episode_process_dumps\s05e02
# Skipping folder episode_process_dumps\s05e03
# Skipping folder episode_process_dumps\s05e04
# Skipping folder episode_process_dumps\s05e05
# Skipping folder episode_process_dumps\s05e06
# Skipping folder episode_process_dumps\s05e07
# Skipping folder episode_process_dumps\s05e08
# Skipping folder episode_process_dumps\s05e09
# Skipping folder episode_process_dumps\s05e10
# Skipping folder episode_process_dumps\s05e11
# Skipping folder episode_process_dumps\s05e12
# Skipping folder episode_process_dumps\s05e13
# Skipping folder episode_process_dumps\s05e14
# Skipping folder episode_process_dumps\s05e15
# Skipping folder episode_process_dumps\s05e16
# Skipping folder episode_process_dumps\s05e17
# Skipping folder episode_process_dumps\s05e18
# Skipping folder episode_process_dumps\s05e19
# Skipping folder episode_process_dumps\s05e20
# Skipping folder episode_process_dumps\s05e21
# Skipping folder episode_process_dumps\s05e22
# Skipping folder episode_process_dumps\s05e23
# Skipping folder episode_process_dumps\s05e24
# Skipping folder episode_process_dumps\s05e25
# Skipping folder episode_process_dumps\s05e26
# Skipping folder episode_process_dumps\s06e01
# Skipping folder episode_process_dumps\s06e02
# Skipping folder episode_process_dumps\s06e03
# Skipping folder episode_process_dumps\s06e04
# Skipping folder episode_process_dumps\s06e05
# Skipping folder episode_process_dumps\s06e06
# Skipping folder episode_process_dumps\s06e07
# Skipping folder episode_process_dumps\s06e08
# Skipping folder episode_process_dumps\s06e09
# Skipping folder episode_process_dumps\s06e10
# Skipping folder episode_process_dumps\s06e11
# Skipping folder episode_process_dumps\s06e12
# Skipping folder episode_process_dumps\s06e13
# Skipping folder episode_process_dumps\s06e14
# Skipping folder episode_process_dumps\s06e15
# Skipping folder episode_process_dumps\s06e16
# Skipping folder episode_process_dumps\s06e17
# Skipping folder episode_process_dumps\s06e18
# Skipping folder episode_process_dumps\s06e19
# Skipping folder episode_process_dumps\s06e20
# Skipping folder episode_process_dumps\s06e21
# Skipping folder episode_process_dumps\s06e22
# Skipping folder episode_process_dumps\s06e23
# Skipping folder episode_process_dumps\s06e24
# Skipping folder episode_process_dumps\s06e25
# Skipping folder episode_process_dumps\s06e26
# Skipping folder episode_process_dumps\s07e01
# Skipping folder episode_process_dumps\s07e02
# Skipping folder episode_process_dumps\s07e03
# Skipping folder episode_process_dumps\s07e04
# Skipping folder episode_process_dumps\s07e05
# Skipping folder episode_process_dumps\s07e06
# Skipping folder episode_process_dumps\s07e07
# Skipping folder episode_process_dumps\s07e08
# Skipping folder episode_process_dumps\s07e09
# Skipping folder episode_process_dumps\s07e10
# Skipping folder episode_process_dumps\s07e11
# Skipping folder episode_process_dumps\s07e12
# Skipping folder episode_process_dumps\s07e13
# Skipping folder episode_process_dumps\s07e14
# Skipping folder episode_process_dumps\s07e15
# Skipping folder episode_process_dumps\s07e16
# Skipping folder episode_process_dumps\s07e17
# Skipping folder episode_process_dumps\s07e18
# Skipping folder episode_process_dumps\s07e19
# Skipping folder episode_process_dumps\s07e20
# Skipping folder episode_process_dumps\s07e21
# Skipping folder episode_process_dumps\s07e22
# Skipping folder episode_process_dumps\s07e23
# Skipping folder episode_process_dumps\s07e24
# Skipping folder episode_process_dumps\s07e25
# Skipping folder episode_process_dumps\s07e26
# processing s08e01
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.480061491465129
# dbfs adjust 6.482706158829792
# done
# processing s08e02
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.6603601596770545
# dbfs adjust 6.639811655457976
# done
# processing s08e03
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.320195333732499
# dbfs adjust 6.314547307732568
# done
# processing s08e04
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.28503522409326
# dbfs adjust 6.279516742127601
# done
# processing s08e05
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.473393234731255
# dbfs adjust 6.461524084952671
# done
# processing s08e06
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.542214172242126
# dbfs adjust 6.541697801459286
# done
# processing s08e07
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.3797956208721835
# dbfs adjust 6.379891601847174
# done
# processing s08e08
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.3277008160246915
# dbfs adjust 6.330638327173073
# done
# processing s08e09
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.705453487538438
# dbfs adjust 6.716868523913806
# done
# processing s08e10
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.353831488726026
# dbfs adjust 6.359683812612534
# done
# processing s08e11
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.623135843868667
# dbfs adjust 6.635391080472033
# done
# processing s08e12
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.452271890586147
# dbfs adjust 6.461573763688143
# done
# processing s08e13
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.60209251999385
# dbfs adjust 6.598193005331357
# done
# processing s08e14
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.962988388012533
# dbfs adjust 6.945694237371178
# done
# processing s08e15
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.6881898756095595
# dbfs adjust 6.713122146583046
# done
# processing s08e16
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.377712027986544
# dbfs adjust 6.357616159914681
# done
# processing s08e17
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.322344643356637
# dbfs adjust 6.356978567895766
# done
# processing s08e18
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 7.065494761987495
# dbfs adjust 7.104744116229
# done
# processing s08e19
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.572316815071314
# dbfs adjust 6.575563007426101
# done
# processing s08e20
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.796525994703632
# dbfs adjust 6.817527011525332
# done
# processing s08e21
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.527941575226361
# dbfs adjust 6.5311589337025175
# done
# processing s08e22
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.668530301359354
# dbfs adjust 6.6589771172189245
# done
# processing s08e23
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.296615307875932
# dbfs adjust 6.304186106072422
# done
# processing s08e24
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.3788349129668305
# dbfs adjust 6.376213384392436
# done
# processing s08e25
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.542854746948798
# dbfs adjust 6.553030161872471
# done
# processing s08e26
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.958824704414987
# dbfs adjust 6.954294140491143
# done
# processing s09e01
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.877679013838453
# dbfs adjust 6.862480076651792
# done
# processing s09e02
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 7.32533746547881
# dbfs adjust 7.310406515564786
# done
# processing s09e03
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.857883287100979
# dbfs adjust 6.903831959380877
# done
# processing s09e04
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.519823865678262
# dbfs adjust 6.521493530210336
# done
# processing s09e05
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.302407558073281
# dbfs adjust 6.311398516990952
# done
# processing s09e06
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.380534506601176
# dbfs adjust 6.368689589013609
# done
# processing s09e07
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.609881593964161
# dbfs adjust 6.623492571046057
# done
# processing s09e08
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.930802701692873
# dbfs adjust 6.906047347307311
# done
# processing s09e09
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.747983498787619
# dbfs adjust 6.754531578772358
# done
# processing s09e10
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.334518571590806
# dbfs adjust 6.32956925329691
# done
# processing s09e11
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.439409461599247
# dbfs adjust 6.428281194461029
# done
# processing s09e12
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.562300152645857
# dbfs adjust 6.5935993437630565
# done
# processing s09e13
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.609000956889403
# dbfs adjust 6.6288852633621715
# done
# processing s09e14
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.389338949014846
# dbfs adjust 6.385870751046912
# done
# processing s09e15
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.802407131540761
# dbfs adjust 6.796536875733452
# done
# processing s09e16
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.261845457290637
# dbfs adjust 6.262932663440775
# done
# processing s09e17
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.631487490898984
# dbfs adjust 6.624848979136594
# done
# processing s09e18
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.445529630784961
# dbfs adjust 6.4421743272795595
# done
# processing s09e19
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.286551138273392
# dbfs adjust 6.284995415446456
# done
# processing s09e20
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.365772362542657
# dbfs adjust 6.36197059599003
# done
# processing s09e21
# extracting center
# applying demucs
# finished applying demucs
# dbfs adjust 6.686539001435403
# dbfs adjust 6.671357155492718
# done
